# %% [markdown]
# # <font color= #8A0829> Simulación matemática.</font>
# ## Bienvenidos
#
#  <font color= #2E9AFE>  Lunes y miércoles (B-203) de 9:00 a 11:00 horas.</font>
#
# - <Strong> Carlos Augusto Arellano Muro </Strong>
#
#
#
# - <Strong> Email: </Strong>  <font color="blue"> carellanomuro@iteso.mx </font>
#
# ___

# %% [markdown]
# ## Descripción de la asignatura
#
# - Solución de problemas de ingeniería de manera óptima.
#
# - Abstracción de fenómenos reales al plano matemático.
#
# - Tratar diferentes escenarios de un mismo problema para definir una mejor solución.
#
# - Uso de herramientas libres para simular fenómenos, sistemas y procesos.
#
# ___
#
# ## Objetivo
#
# Reproducir escenarios de aplicación profesional a través de modelar fenómenos físicos y así inferir decisiones que permitan la óptima solución a diversos problemas.

# %% [markdown]
# ## Temario
# **Descripción de Python y librerías**
#
#     1. Introducción y motivación
#     2. Herramientas y entorno de simulación (Python)
#         a. Tipos de variables y operadores
#         b. Control de flujo
#         c. Funciones
#         d. Librerías
#
# `Módulo 1.` **Optimización**
# > Se aplicará una evaluación (**examen**) y se evaluará una presentación de **proyecto.**
#
#     1. Optimización de funciones de variable escalar
#     2. Programación Lineal
#     3. Programación cuadrática
#
# `Módulo 2.` **Métodos heurísticos**
# > Se aplicará una evaluación (**examen**) y se evaluará una presentación de **proyecto.**
#
#     1. Caminata aleatoria
#     2. Simulación de probabilidad con Montecarlo
#
# `Módulo 3.`  **Métodos de búsqueda**
# > Sólo se evaluará una presentación de **proyecto.**
#
#     1. Simulated Annealing

# %% [markdown]
# ## Evaluación
#
# - **3 Proyectos (trabajo en equipo) 50%**
#     - Cada proyecto tiene el mismo valor (16.66%)
#     - La evaluación de cada proyecto se divide en dos partes
#         - Reporte     50%
#         - Exposición  50%
# - **2 Examenes  30%**
# - **Tareas y actividades de clase 20%**

# %% [markdown]
# ## Bibliografía
# - Process Dynamics: Modeling, Analysis and Simulation by B. Wayne Bequette
# - Stochastic Simulation and Applications in Financewith MATLAB Programs by HuuTueHuynh
# - Fluent Python by Ramalho, Luciano
# - Python for Scientists by Stewart, John M.
# - Mathematical Modeling in Continuum Mechanics by Temam & Miranville
#
# ---

# %% [markdown]
# ---
# # Introducción
#
# ## ¿Qué es simulación?
#
# - Motivación y definiciones básicas.
#
# - Descripción de las herramientas que se usarán en el curso.

# %% [markdown]
# ___
# **¿Por qué hacer simulación?**
#
# - Reducción de costos: la simulación es mucho menos costosa que la experimentación en la vida real.
# - Se pueden probar diferentes ideas en un mismo escenario.
# - Se puede determinar el impacto potencial de eventos aleatorios (inversión).
# - Evaluar si ciertos procesos son viables (determinar el impacto a largo plazo).
# - ...
#
# <img style="center" src="https://upload.wikimedia.org/wikipedia/commons/4/4a/FAE_visualization.jpg" width="350px" height="200px" alt="atom" />
#
# _Referencia:_
# _Simulation Fundamentals,  B. S. Bennett_

# %% [markdown]
# **Definiciones**
#
# - Simulación
# - Sistema
# - Modelo

# %% [markdown]
# ____
# ### Herramientas computacionales
#
# - [python](https://www.python.org)
# - [Anaconda](https://www.anaconda.com/distribution/)
# - [Jupyter](http://jupyter.org)
# - [Google Colab](https://colab.research.google.com/)
#
# <img style="float: left" src="https://www.python.org/static/community_logos/python-logo.png" width="150px" />
#
# <img style="float: left" src="https://upload.wikimedia.org/wikipedia/en/c/cd/Anaconda_Logo.png" width="100" />
#
# <img style="float: left" src="https://jupyter.org/assets/homepage/main-logo.svg" width="50" />

# %% [markdown]
# ---
# # Ejemplos de Markdown
# `Ctrl`+`M`, `M` $\rightarrow$ Cambia una celda de código a markdown.

# %% [markdown]
# Ecuaciones dentro del párrafo: $x_1+x_2^2=\frac{1}{2}$.
#
# Ecuaciones fuera del párrafo:
# $$
# \nabla\cdot f=\frac{\partial}{\partial x_1}f+\frac{\partial}{\partial x_2}f
# $$
# Letras griegas: $\alpha$, $\sum_{i=0}^{\infty}\lambda^{-i}$
# $$
# \int_0^1\int dx=\sin(\pi)
# $$

# %% [markdown]
# ## Algunos comandos de teclado
# * `Ctrl`+`M`,`M` $\rightarrow$ Cambia una celda de **código** a markdown.
#
# * `Ctrl`+`M`,`Y` $\rightarrow$ Cambia una celda de **markdown** a código.
#
# * `Esc`,`A` $\rightarrow$ Crea una celda de código por *encima*.
#
# * `Esc`,`B` $\rightarrow$ Crea una celda de código por _debajo_.
#
# * `Ctrl`+`M`,`D` $\rightarrow$ ~Borrar~ una celda.
#
# * `Ctrl`+`Enter` $\rightarrow$ Solo ejecutar una celda.
#
# * `Alt`+`Enter` $\rightarrow$ Ejecutar una celda y crear otra.
#
# * `Shift`+`Enter` $\rightarrow$ Ejecutar una celda y pasar a la siguiente.

# %% [markdown]
# ## Repositorio en `GitHub`
# <img style="float: left; margin: 15px 15px 15px 15px;" src="https://c1.staticflickr.com/3/2238/13158675193_2892abac95_z.jpg" title="github" width="180"/>

# %% [markdown]
# **Repositorio de la materia:** https://github.com/ArellanoMCarlos/SimMatO2025
#
# ---
# Además, crear un repositorio para tareas. Deberán subir el enlace de GitHub, propio del archivo, a Canvas.
#
# ### Primera tarea: Uso de `Markdown`
# > Crear una archivo con extensión ipynb con una presentación personal y un resumen de un artículo o noticia, usando formato de texto propio de Markdown.

# %% [markdown]
# ## Recomendación: `git`, `GitHub`, `GitKraken`
#
# <img style="float: left; margin: 15px 15px 15px 15px;" src="http://conociendogithub.readthedocs.io/en/latest/_images/Git.png" width="180"/>
# <img style="float: left; margin: 15px 15px 15px 15px;" src="https://c1.staticflickr.com/3/2238/13158675193_2892abac95_z.jpg" title="github" width="180"/>
# <img style="float: left; margin: 15px 15px 15px 15px;" src="https://www.gitkraken.com/wp-content/uploads/2021/06/gitkraken-logo-dark-sq.png" title="gitkraken" width="110" />
